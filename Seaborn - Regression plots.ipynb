# %% [markdown]
# # regression plots

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
mpg_data=pd.read_csv('auto-mpg.csv')
mpg_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
#replace missing data
mpg_data.replace('.',np.nan,inplace=True)
mpg_data.replace('?',np.nan,inplace=True)
mpg_data=mpg_data.dropna()
mpg_data.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
mpg_data['horsepower']=mpg_data['horsepower'].astype(int)

# %%
sns.lmplot(x='horsepower',y='mpg',data=mpg_data)

# %%
sns.lmplot(x='horsepower',y='mpg',hue='origin',aspect=1.5,data=mpg_data)

# %%
sns.lmplot(x='horsepower',y='mpg',hue='origin',palette='Set2',aspect=1.5,data=mpg_data)

# %%
sns.lmplot(x='cylinders',y='mpg',aspect=1.5,data=mpg_data)

# %%
sns.lmplot(x='weight',y='mpg',data=mpg_data,col='origin')

# %%
sns.pairplot(mpg_data,height=3,
            vars=['mpg','acceleration','horsepower'],
                 kind='reg')
