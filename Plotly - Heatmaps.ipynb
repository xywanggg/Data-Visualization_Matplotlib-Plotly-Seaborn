# %% [markdown]
# # Heatmaps

# %%
import plotly.graph_objs as go
import plotly.offline as offline

offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from IPython.display import Image

# %%
trace=go.Heatmap(z=[[8,64],[3,37]])

# %%
data=[trace]
offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="ca17640d-6c81-4177-a8ce-157d930d532e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca17640d-6c81-4177-a8ce-157d930d532e")) {
#                     Plotly.newPlot(
#                         'ca17640d-6c81-4177-a8ce-157d930d532e',
#                         [{"type": "heatmap", "z": [[8, 64], [3, 37]]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
Image('newplot.png')

# %%
import pandas as pd
housing_data=pd.read_csv('housing.csv')
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14969    -117.01     32.75                34.0       2105.0           340.0
# 6512     -118.03     34.07                37.0       1091.0           269.0
# 9790     -121.84     36.25                20.0        958.0           245.0
# 4733     -118.36     34.05                50.0       3518.0           812.0
# 17801    -121.79     37.38                22.0       3650.0           527.0
#
#        population  households  median_income  median_house_value  \
# 14969       973.0       357.0         4.3088            152500.0
# 6512        905.0       242.0         3.1042            152000.0
# 9790        590.0       189.0         2.6094            362500.0
# 4733       1724.0       758.0         3.0833            338100.0
# 17801      1637.0       520.0         5.3774            325600.0
#
#       ocean_proximity
# 14969       <1H OCEAN
# 6512        <1H OCEAN
# 9790       NEAR OCEAN
# 4733        <1H OCEAN
# 17801       <1H OCEAN

# %%
housing_data.shape
# Out:
# (20640, 10)

# %%
housing_data=housing_data.sample(frac=0.1).reset_index(drop=True)
housing_data.shape
# Out:
# (2064, 10)

# %%
median=housing_data['median_house_value'].median()
median
# Out:
# 181250.0

# %%
housing_data['above_median']=(housing_data['median_house_value']-median)>0
housing_data.sample(5)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1861    -121.29     38.76                12.0       1198.0           174.0
# 1106    -121.93     36.62                34.0       2351.0             NaN
# 446     -118.95     35.37                37.0       1475.0           327.0
# 1145    -118.31     33.81                23.0       3942.0           748.0
# 1725    -119.99     38.94                24.0       1216.0           289.0
#
#       population  households  median_income  median_house_value  \
# 1861       443.0       170.0         6.0097            187500.0
# 1106      1063.0       428.0         3.7250            278000.0
# 446        946.0       295.0         1.6728             55400.0
# 1145      1679.0       711.0         4.1169            362600.0
# 1725       421.0       185.0         3.1625            103600.0
#
#      ocean_proximity  above_medain  above_median
# 1861          INLAND          True          True
# 1106      NEAR OCEAN          True          True
# 446           INLAND         False         False
# 1145       <1H OCEAN          True          True
# 1725          INLAND         False         False

# %%
trace=go.Heatmap(z=housing_data['median_house_value'],
                x=housing_data['ocean_proximity'],
                y=housing_data['above_median'],
                colorscale='Jet',
                reversescale=True)

# %%
data=[trace]
offline.iplot(data)
# Out:
# <div>
#
#
#             <div id="71690bf0-f964-4d47-b9f0-7971cf75d125" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("71690bf0-f964-4d47-b9f0-7971cf75d125")) {
#                     Plotly.newPlot(
#                         '71690bf0-f964-4d47-b9f0-7971cf75d125',
#                         [{"colorscale": [[0.0, "rgb(0,0,131)"], [0.2, "rgb(0,60,170)"], [0.4, "rgb(5,255,255)"], [0.6, "rgb(255,255,0)"], [0.8, "rgb(250,0,0)"], [1.0, "rgb(128,0,0)"]], "reversescale": true, "type": "heatmap", "x": ["INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR OCEAN", "NEAR BAY", "NEAR BAY", "<1H OCEAN", "NEAR OCEAN", "INLAND", "NEAR BAY", "NEAR OCEAN", "NEAR BAY", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR OCEAN", "NEAR BAY", "INLAND", "INLAND", "INLAND", "NEAR OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "INLAND", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "NEAR OCEAN", "NEAR BAY", "INLAND", "NEAR OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "NEAR OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "NEAR OCEAN", "NEAR BAY", "INLAND", "INLAND", "<1H OCEAN", "NEAR BAY", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "NEAR BAY", "INLAND", "NEAR OCEAN", "INLAND", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR BAY", "NEAR OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "NEAR BAY", "NEAR OCEAN", "INLAND", "NEAR BAY", "NEAR BAY", "INLAND", "INLAND", "<1H OCEAN", "NEAR OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR BAY", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "NEAR OCEAN", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "INLAND", "NEAR BAY", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "INLAND", "NEAR OCEAN", "NEAR OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEAN", "NEAR BAY", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR BAY", "INLAND", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "NEAR BAY", "NEAR BAY", "NEAR OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "NEAR BAY", "INLAND", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "INLAND", "<1H OCEAN", "NEAR OCEAN", "<1H OCEAN", "<1H OCEAN", "<1H OCEAN", "NEAR OCEAN", "INLAND", "INLAND", "<1H OCEAN", "INLAND", "INLAND", "INLAND", "<1H OCEAN", "NEAR BAY", "<1H OCEAN", "INLAND", "INLAND", "<1H OCEA ...

# %%
Image('newplot2.png')
